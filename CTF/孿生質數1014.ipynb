# %% [markdown]
# <a href="https://colab.research.google.com/github/HAUNYuHan/20210913/blob/master/%E5%AD%BF%E7%94%9F%E8%B3%AA%E6%95%B8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pycrypto
# Out:
# ...
#      |████████████████████████████████| 446 kB 30.9 MB/s
# ...
#   Created wheel for pycrypto: filename=pycrypto-2.6.1-cp37-cp37m-linux_x86_64.whl size=499932 sha256=a0594d4eddac1d0f822589e8693d697f202b18bef3f40dd0d2b2fa5855534440
#   Stored in directory: /root/.cache/pip/wheels/cf/85/ba/bbd7c96add459de7598fb424e5ff2309baf2095c844ac0f191
# Successfully built pycrypto
# ...

# %%
c = ...

e = 10000001

n1 = ...

n2 = ...

# %%
#!/usr/bin/env python
from Crypto.Util.number import *
# import gmpy2
from sympy import mod_inverse

c = ...

e = 10000001

n1 = ...

n2 = ...


p_q = (n2 - n1 - 4) // 2  # p_q ==p+q

n1_phi = n1 - p_q + 1
n2_phi = n1 + p_q + 1

#d1 = int(gmpy2.invert(e, n1_phi))
#d2 = int(gmpy2.invert(e, n2_phi))
d1 = mod_inverse(e, n1_phi)
d2 = mod_inverse(e, n2_phi)

m = pow(pow(c,d2,n2),d1,n1)
print(long_to_bytes(m))
# Out:
# b'BreakALLCTF{twin_is_Soooooooooooo_Easy_in_RSaaaaaaaaaaaaaa}'
